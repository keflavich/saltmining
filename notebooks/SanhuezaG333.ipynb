# %% [markdown]
# distance from http://simbad.cds.unistra.fr/simbad/sim-ref?bibcode=2017AJ....154..140W -> https://ui.adsabs.harvard.edu/abs/2017AJ....154..140W/abstract
#
# http://simbad.cds.unistra.fr/simbad/sim-coo?Coord=333.23+-0.06&CooFrame=Gal&CooEpoch=2000&CooEqui=2000&CooDefinedFrames=none&Radius=2&Radius.unit=arcmin&submit=submit+query&CoordList=

# %% [markdown]
# Poorly studied with interferometers.
#
# Only reference:
# https://ui.adsabs.harvard.edu/abs/2015ApJ...802....6S/abstract
#
# ATCA 2.4" resolution.
#
# Bottom-left source is ATCA mm1, top-right sources is ATCA mm2.  Middle source is unnamed

# %%
from astropy import units as u
distance=5.3*u.kpc
vcen = -87.2 * u.km/u.s # from Patricio
#vcen = -102*u.km/u.s # based on my examination

# %%
cd /orange/adamginsburg/salt/sanhueza/G333/
# Out:
# /orange/adamginsburg/salt/sanhueza/G333

# %%
# CARTA loading script

field = 'G333.23-0.06'
dirfield = 'G333'
spwmap = {
0: 234.251912,
1: 232.6867,
2: 217.817644,
3: 219.614936,
}
basepath = f"/salt/sanhueza/{dirfield}"
print(f"""const frame = await app.appendFile("{basepath}/{field}.config8.cont_avg.selfcal_0.5_hogbom.image.fits");\n""")
for spw in (0,1,2,3):
      print(f"""
const frame{spw} = await app.appendFile("{basepath}/{field}.config8.spw{spw}.robust0.5.image_small.fits");
frame{spw}.restFreqStore.setCustomUnit("GHz");
frame{spw}.restFreqStore.setCustomVal({spwmap[spw]});
""")
# Out:
# const frame = await app.appendFile("/salt/sanhueza/G333/G333.23-0.06.config8.cont_avg.selfcal_0.5_hogbom.image.fits");
#
#
# const frame0 = await app.appendFile("/salt/sanhueza/G333/G333.23-0.06.config8.spw0.robust0.5.image_small.fits");
# frame0.restFreqStore.setCustomUnit("GHz");
# frame0.restFreqStore.setCustomVal(234.251912);
#
#
# const frame1 = await app.appendFile("/salt/sanhueza/G333/G333.23-0.06.config8.spw1.robust0.5.image_small.fits");
# frame1.restFreqStore.setCustomUnit("GHz");
# frame1.restFreqStore.setCustomVal(232.6867);
#
#
# const frame2 = await app.appendFile("/salt/sanhueza/G333/G333.23-0.06.config8.spw2.robust0.5.image_small.fits");
# frame2.restFreqStore.setCustomUnit("GHz");
# frame2.restFreqStore.setCustomVal(217.817644);
#
#
# const frame3 = await app.appendFile("/salt/sanhueza/G333/G333.23-0.06.config8.spw3.robust0.5.image_small.fits");
# frame3.restFreqStore.setCustomUnit("GHz");
# frame3.restFreqStore.setCustomVal(219.614936);

# %%
ls
# Out:
# cutout2.reg
# cutout3.reg
# cutout.reg
# G333.23-0.06.config8.cont_avg.selfcal_0.5_hogbom.image.fits
# G333.23-0.06.config8.spw0.robust0.5.image_co1_smaller.fits
# G333.23-0.06.config8.spw0.robust0.5.image_co2_smaller.fits
# G333.23-0.06.config8.spw0.robust0.5.image_small.fits
# G333.23-0.06.config8.spw1.robust0.5.image_co1_smaller.fits
# G333.23-0.06.config8.spw1.robust0.5.image_co2_smaller.fits
# G333.23-0.06.config8.spw1.robust0.5.image_small.fits
# G333.23-0.06.config8.spw2.robust0.5.image_co1_smaller.fits
# G333.23-0.06.config8.spw2.robust0.5.image_co2_smaller.fits
# G333.23-0.06.config8.spw2.robust0.5.image_small.fits
# G333.23-0.06.config8.spw3.robust0.5.image_co1_smaller.fits
# G333.23-0.06.config8.spw3.robust0.5.image_co2_smaller.fits
# G333.23-0.06.config8.spw3.robust0.5.image_small.fits
# NaCl_v_le_3_stackcube.fits
# spectra/

# %%
# %matplotlib inline
import pylab as pl
pl.rcParams['figure.facecolor'] = 'w'
from spectral_cube import SpectralCube
from astropy import units as u
from astropy.visualization import quantity_support
quantity_support()
# Out:
# <astropy.visualization.units.quantity_support.<locals>.MplQuantityConverter at 0x2b568bb64f10>

# %%
from astropy.table import Table
from astropy import table

# %%
import pprint

# %%
import scipy, scipy.ndimage

# %%
import numpy as np
import os
import glob
from astropy import constants, units as u, table, stats, coordinates, wcs, log, coordinates as coord
import radio_beam
import pyspeckit
import pylab as pl
from astroquery.splatalogue.utils import minimize_table as mt
import sys
sys.path.append('/orange/adamginsburg/salt/Orion_ALMA_2016.1.00165.S/analysis')
import lines
import paths
from astropy import visualization
from salt_tables import (salt_tables, salt_table_names, SO, SO2, HCl, sis_tables, AlCl, AlF, Al37Cl,
                         NaF, AlO, AlOH, NaCN, CaS, CaO)

# %%
import regions
from astropy import units as u, coordinates
mm1 = reg = regions.Regions.read('cutout.reg')
mm2 = reg2 = regions.Regions.read('cutout2.reg')
#regvsm = regions.Regions.read('verysmall.reg')
#regvvsm = regions.Regions.read('innerdiskbox.reg')

# %%
reg[0].center.to_string('hmsdms')
# Out:
# '16h19m51.27528s -50d15m14.5584s'

# %%
reg2[0].center.to_string('hmsdms')
# Out:
# '16h19m50.88096s -50d15m10.5624s'

# %%
reg[0].center.galactic
# Out:
# <SkyCoord (Galactic): (l, b) in deg
#     (333.23388724, -0.06170149)>

# %%
cont = SpectralCube.read('G333.23-0.06.config8.cont_avg.selfcal_0.5_hogbom.image.fits')[:,2000:3000,2000:3000]
pl.figure(figsize=(10,10))
ax = pl.subplot(projection=cont[0].wcs)
ax.imshow(cont[0].value, cmap='gray_r', norm=visualization.simple_norm(cont[0].value, stretch='log'))
reg[0].to_pixel(cont[0].wcs).plot(ax=ax)
reg2[0].to_pixel(cont[0].wcs).plot(ax=ax)
#regvsm[0].to_pixel(cont[0].wcs).plot(ax=ax)
#regvvsm[0].to_pixel(cont[0].wcs).plot(ax=ax)
#pp = reg[0].to_pixel(cont.wcs.celestial)
#bb = pp.bounding_box
#ax.axis([bb.ixmin-20, bb.ixmax+20, bb.iymin-20, bb.iymax+20])
# Out:
# WARNING: StokesWarning: Cube is a Stokes cube, returning spectral cube for I component [spectral_cube.io.core]
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# <WCSAxesSubplot:>

# %% [markdown]
# # NaCl Stackl

# %%
from spectral_cube.analysis_utilities import stack_cube

# %%
nacltables = salt_tables[3:5]
#nacltables[0]

# %%
import spectral_cube.analysis_utilities
import imp
imp.reload(spectral_cube.analysis_utilities)
from spectral_cube.analysis_utilities import stack_cube

# %%
flist = (glob.glob('G333.23-0.06.config8.spw[0-3].robust0.5.image_small.fits'))

# %%
for fn in flist:
    for rr,regn in ((reg, 'co1'), (reg2, 'co2')):
        outfile = fn.replace("_small",f"_{regn}_smaller")
        if not os.path.exists(outfile):
            cube = SpectralCube.read(fn).subcube_from_regions(rr)
            cube.allow_huge_operations=True
            cb = cube.beams.common_beam(max_iter=20, max_epsilon=0.01)
            scube = cube.convolve_to(cb).to(u.K)
            scube.write(outfile, overwrite=True)

# %%
regn = "co1"
cubes = [SpectralCube.read(fn, use_dask=True).subcube_from_regions(reg)
         for fn in (glob.glob(f'G333.23-0.06.config8.spw[0-3].robust0.5.image_{regn}_smaller.fits'))]

cubes
# Out:
# [DaskSpectralCube with shape=(3840, 48, 47) and unit=K and chunk size (3840, 48, 47):
#   n_x:     47  type_x: RA---SIN  unit_x: deg    range:   244.963547 deg:  244.963747 deg
#   n_y:     48  type_y: DEC--SIN  unit_y: deg    range:   -50.254109 deg:  -50.253979 deg
#   n_s:   3840  type_s: FREQ      unit_s: Hz     range: 233563396491.200 Hz:235438023434.076 Hz,
#  DaskSpectralCube with shape=(3840, 48, 47) and unit=K and chunk size (3840, 48, 47):
#   n_x:     47  type_x: RA---SIN  unit_x: deg    range:   244.963547 deg:  244.963747 deg
#   n_y:     48  type_y: DEC--SIN  unit_y: deg    range:   -50.254109 deg:  -50.253979 deg
#   n_s:   3840  type_s: FREQ      unit_s: Hz     range: 219063352591.324 Hz:220937979534.200 Hz,
#  DaskSpectralCube with shape=(3840, 48, 47) and unit=K and chunk size (3840, 48, 47):
#   n_x:     47  type_x: RA---SIN  unit_x: deg    range:   244.963547 deg:  244.963747 deg
#   n_y:     48  type_y: DEC--SIN  unit_y: deg    range:   -50.254109 deg:  -50.253979 deg
#   n_s:   3840  type_s: FREQ      unit_s: Hz     range: 231063388922.300 Hz:232938015865.176 Hz,
#  DaskSpectralCube with shape=(3840, 48, 47) and unit=K and chunk size (3840, 48, 47):
#   n_x:     47  type_x: RA---SIN  unit_x: deg    range:   244.963547 deg:  244.963747 deg
#   n_y:     48  type_y: DEC--SIN  unit_y: deg    range:   -50.254109 deg:  -50.253979 deg
#   n_s:   3840  type_s: FREQ      unit_s: Hz     range: 216863345930.624 Hz:218737972873.500 Hz]

# %%
regn = "co2"
cubes2 = [SpectralCube.read(fn, use_dask=True).subcube_from_regions(reg2)
         for fn in (glob.glob(f'G333.23-0.06.config8.spw[0-3].robust0.5.image_{regn}_smaller.fits'))]

cubes2
# Out:
# [DaskSpectralCube with shape=(3840, 39, 37) and unit=K and chunk size (3840, 39, 37):
#   n_x:     37  type_x: RA---SIN  unit_x: deg    range:   244.961927 deg:  244.962083 deg
#   n_y:     39  type_y: DEC--SIN  unit_y: deg    range:   -50.252987 deg:  -50.252882 deg
#   n_s:   3840  type_s: FREQ      unit_s: Hz     range: 219063352591.324 Hz:220937979534.200 Hz,
#  DaskSpectralCube with shape=(3840, 39, 37) and unit=K and chunk size (3840, 39, 37):
#   n_x:     37  type_x: RA---SIN  unit_x: deg    range:   244.961927 deg:  244.962083 deg
#   n_y:     39  type_y: DEC--SIN  unit_y: deg    range:   -50.252987 deg:  -50.252882 deg
#   n_s:   3840  type_s: FREQ      unit_s: Hz     range: 216863345930.624 Hz:218737972873.500 Hz,
#  DaskSpectralCube with shape=(3840, 39, 37) and unit=K and chunk size (3840, 39, 37):
#   n_x:     37  type_x: RA---SIN  unit_x: deg    range:   244.961927 deg:  244.962083 deg
#   n_y:     39  type_y: DEC--SIN  unit_y: deg    range:   -50.252987 deg:  -50.252882 deg
#   n_s:   3840  type_s: FREQ      unit_s: Hz     range: 233563396491.200 Hz:235438023434.076 Hz,
#  DaskSpectralCube with shape=(3840, 39, 37) and unit=K and chunk size (3840, 39, 37):
#   n_x:     37  type_x: RA---SIN  unit_x: deg    range:   244.961927 deg:  244.962083 deg
#   n_y:     39  type_y: DEC--SIN  unit_y: deg    range:   -50.252987 deg:  -50.252882 deg
#   n_s:   3840  type_s: FREQ      unit_s: Hz     range: 231063388922.300 Hz:232938015865.176 Hz]

# %%
# only needed for VRSCs
if hasattr(cubes[0], 'beams'):
    beams = radio_beam.Beams(beams=[cube.beams.common_beam(max_iter=20, max_epsilon=0.01) for cube in cubes])
    cb=beams.common_beam()
else:
    beams = radio_beam.Beams(beams=[cube.beam for cube in cubes])
    cb=beams.common_beam()

# %%
cb
# Out:
# Beam: BMAJ=0.07612335681915276 arcsec BMIN=0.058185502886771996 arcsec BPA=58.16907501220703 deg

# %%
(cb.major*distance).to(u.au, u.dimensionless_angles())
# Out:
# <Quantity 403.45379114 AU>

# %%
(cb.minor*distance).to(u.au, u.dimensionless_angles())
# Out:
# <Quantity 308.3831653 AU>

# %%
linelist = np.concatenate([data['Freq'][(data['vu'] <= 3) &
                                          np.any([((data['Freq'].quantity > cube.spectral_extrema[0]) &
                                                   (data['Freq'].quantity < cube.spectral_extrema[1]))
                                                 for cube in cubes],
                                                 axis=0)].quantity
                             for data in nacltables])
linenames = np.concatenate( [data['Species'][(data['vu'] <= 3) &
                                          np.any([((data['Freq'].quantity > cube.spectral_extrema[0]) &
                                                   (data['Freq'].quantity < cube.spectral_extrema[1]))
                                                 for cube in cubes],
                                                 axis=0)]
                             for data in nacltables] )
(linelist, linenames)
# Out:
# (<Quantity [217.980231, 219.614936, 232.509977, 234.251912] GHz>,
#  array(['23Na-35Clv=2-2 J=17-16', '23Na-35Clv=1-1 J=17-16',
#         '23Na-35Clv=1-1 J=18-17', '23Na-35Clv=0-0 J=18-17'], dtype='<U24'))

# %%
from astropy import log
log.setLevel('INFO')

# %%
#log.setLevel('DEBUG')
vcen = -87.2 * u.km/u.s # from Patricio
stack, cutouts = stack_cube(cubes,
                   linelist=linelist,
                   vmin=vcen-30*u.km/u.s,
                   vmax=vcen+30*u.km/u.s,
                   average=np.nanmean,
                   convolve_beam=cb,
                   return_cutouts=True)
#log.setLevel('INFO')
stack.write('NaCl_v_le_3_stackcube.fits', overwrite=True)
# Out:
# WARNING: SliceWarning: The maxmimum and minimum spectral channel in the spectralslab are identical; this indicates that one or both are likely incorrect and/or out of range. [spectral_cube.spectral_cube]
# WARNING: SliceWarning: The maxmimum and minimum spectral channel in the spectralslab are identical; this indicates that one or both are likely incorrect and/or out of range. [spectral_cube.spectral_cube]
# WARNING: SliceWarning: The maxmimum and minimum spectral channel in the spectralslab are identical; this indicates that one or both are likely incorrect and/or out of range. [spectral_cube.spectral_cube]
# WARNING: SliceWarning: The maxmimum and minimum spectral channel in the spectralslab are identical; this indicates that one or both are likely incorrect and/or out of range. [spectral_cube.spectral_cube]
# WARNING: SliceWarning: The maxmimum and minimum spectral channel in the spectralslab are identical; this indicates that one or both are likely incorrect and/or out of range. [spectral_cube.spectral_cube]
# WARNING: SliceWarning: The maxmimum and minimum spectral channel in the spectralslab are identical; this indicates that one or both are likely incorrect and/or out of range. [spectral_cube.spectral_cube]
# WARNING: SliceWarning: The maxmimum and minimum spectral channel in the spectralslab are identical; this indicates that one or both are likely incorrect and/or out of range. [spectral_cube.spectral_cube]
# WARNING: SliceWarning: The maxmimum and minimum spectral channel in the spectralslab are identical; this indicates that one or both are likely incorrect and/or out of range. [spectral_cube.spectral_cube]
# WARNING: SliceWarning: The maxmimum and minimum spectral channel in the spectralslab are identical; this indicates that one or both are likely incorrect and/or out of range. [spectral_cube.spectral_cube]
# WARNING: SliceWarning: The maxmimum and minimum spectral channel in the spectralslab are identical; this indicates that one or both are likely incorrect and/or out of range. [spectral_cube.spectral_cube]
# WARNING: SliceWarning: The maxmimum and minimum spectral channel in the spectralslab are identical; this indicates that one or both are likely incorrect and/or out of range. [spectral_cube.spectral_cube]
# WARNING: SliceWarning: The maxmimum and minimum spectral channel in the spectralslab are identical; this indicates that one or both are likely incorrect and/or out of range. [spectral_cube.spectral_cube]

# %%
stackc = SpectralCube.read('NaCl_v_le_3_stackcube.fits', use_dask=True)
stackc
# Out:
# DaskSpectralCube with shape=(91, 48, 47) and unit=K and chunk size (91, 48, 47):
#  n_x:     47  type_x: RA---SIN  unit_x: deg    range:   244.963547 deg:  244.963747 deg
#  n_y:     48  type_y: DEC--SIN  unit_y: deg    range:   -50.254109 deg:  -50.253979 deg
#  n_s:     91  type_s: VRAD      unit_s: km / s  range:     -117.366 km / s:     -56.923 km / s

# %%
jtok = stackc.beam.jtok(217*u.GHz)

# %%
stackc = stackc.subcube_from_regions(reg)
pl.figure(figsize=(14,5))
pl.subplot(1,3,1)
m0 = stackc.moment0()
m0.quicklook()
pl.title("m0")

pl.subplot(1,3,2)
mx = stackc.max(axis=0)
mx.quicklook()
pl.title("mx")
pl.colorbar()
pl.subplot(1,3,3)
msk = mx > 0.0001*mx.unit*jtok.value
msk = scipy.ndimage.binary_erosion(msk, iterations=1)
msk = scipy.ndimage.binary_dilation(msk, iterations=5)
pl.imshow(msk, interpolation='none', origin='lower')
pl.title('mask')
pl.tight_layout()
pl.figure()


m1 = stackc.with_mask(msk).with_mask(stackc > 0.0001*stackc.unit*jtok.value).moment1()
pl.figure(figsize=(14,6))
ax1 = pl.subplot(1,2,1)
im = ax1.imshow(m1.value, vmin=-10, vmax=10)
pl.colorbar(mappable=im)
mxv = stackc.with_mask(msk).argmax_world(axis=0)
pl.subplot(1,2,2)
pl.imshow(mxv.value, vmin=-10, vmax=10)
pl.colorbar()


vmap = m1.hdu
# Out:
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.argmax_world at 0x2b56689951f0>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]

# %%
vcen
# Out:
# <Quantity -87.2 km / s>

# %%
# try creating a vmap based on another line
restval = 232.6867*u.GHz # 'H2Ov2=1_5(5,0)-6(4,3)': 
restval = 218.440063*u.GHz # CH3OH 4-3
restval = 219.94944000*u.GHz # SO 65-54
cube = [c for c in cubes if (c.spectral_extrema[0] < restval) & (c.spectral_extrema[1] > restval)][0]
scube = (cube.subcube_from_regions(reg)
         .with_spectral_unit(u.km/u.s,
                                                          velocity_convention='radio',
                                                          rest_value=restval)
         .spectral_slab(vcen-30*u.km/u.s, vcen+30*u.km/u.s))
pl.figure(figsize=(14,5))
pl.subplot(1,3,1)
m0 = scube.moment0()
m0.quicklook()
pl.title("m0")
pl.colorbar()

pl.subplot(1,3,2)
mx = scube.max(axis=0)
mx.quicklook()
pl.title("mx")
pl.colorbar()
pl.subplot(1,3,3)
msk = (mx > 80*u.K) #& (m0 > 1450*u.K*u.km/u.s)
msk = scipy.ndimage.binary_erosion(msk, iterations=1)
msk = scipy.ndimage.binary_dilation(msk, iterations=3)
pl.imshow(msk, interpolation='none', origin='lower')
pl.title('mask')
pl.tight_layout()
pl.figure()


from dask_image.ndmorph import binary_dilation, binary_erosion
m3d = (scube > 70*u.K).include()
m3d = binary_erosion(m3d, iterations=1)
m3d = binary_dilation(m3d, iterations=3)
m3d = m3d.compute()

m1 = scube.with_mask(msk).with_mask(m3d).moment1()
pl.figure(figsize=(14,6))
ax1 = pl.subplot(1,2,1)
im = ax1.imshow(m1.value, vmin=vcen.value-10, vmax=vcen.value+10)
pl.colorbar(mappable=im)
mxv = scube.with_mask(msk).argmax_world(axis=0)
pl.subplot(1,2,2)
pl.imshow(mxv.value, vmin=vcen.value-10, vmax=vcen.value+10)
pl.colorbar()


vmap = m1.hdu
# the rest value selected above was just the line center; we need to assume it's really 32 km/s off
#vmap.data = vmap.data
# Out:
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.argmax_world at 0x2b56689951f0>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]

# %%
import sys
sys.path.append('/orange/adamginsburg/salt/code/')
from overplot_saltlines import overplot_saltlines

# %%
spectra = []
for ii,cube in enumerate(cubes):
    cube.allow_huge_operations=True
    sp = cube.subcube_from_regions(reg).mean(axis=(1,2))
    pysp = pyspeckit.Spectrum(data=sp, xarr=sp.spectral_axis, header=sp.header)
    spectra.append(pysp)
    pysp.specname = f'spw{ii+1}'

# %%
mkdir -p spectra/figures

# %%
overplot_saltlines(spectra, vcen=vcen, savepath='spectra/figures', ymin=-10, ymax=50)
# Out:
# spw1
# spw2
# spw3
# spw4

# %%
ls spectra/figures
# Out:
# color_labels_G333_06_stack.png
# color_labels_G333_spw0_mm2_stack.png
# color_labels_G333_spw0_stack.png
# color_labels_G333_spw1_mm2_stack.png
# color_labels_G333_spw1_stack.png
# color_labels_G333_spw2_mm2_stack.png
# color_labels_G333_spw2_stack.png
# color_labels_G333_spw3_mm2_stack.png
# color_labels_G333_spw3_stack.png
# color_labels_spw1.png
# color_labels_spw2.png
# color_labels_spw3.png
# color_labels_spw4.png
# G333_06_stack.png
# G333.23-0.06.config8.spw0.robust0.5.image_co1_smaller_stack.pdf
# G333.23-0.06.config8.spw0.robust0.5.image_co1_smaller_stack.png
# G333.23-0.06.config8.spw0.robust0.5.image_co2_smaller_mm2_stack.pdf
# G333.23-0.06.config8.spw0.robust0.5.image_co2_smaller_mm2_stack.png
# G333.23-0.06.config8.spw1.robust0.5.image_co1_smaller_stack.pdf
# G333.23-0.06.config8.spw1.robust0.5.image_co1_smaller_stack.png
# G333.23-0.06.config8.spw1.robust0.5.image_co2_smaller_mm2_stack.pdf
# G333.23-0.06.config8.spw1.robust0.5.image_co2_smaller_mm2_stack.png
# G333.23-0.06.config8.spw2.robust0.5.image_co1_smaller_stack.pdf
# G333.23-0.06.config8.spw2.robust0.5.image_co1_smaller_stack.png
# G333.23-0.06.config8.spw2.robust0.5.image_co2_smaller_mm2_stack.pdf
# G333.23-0.06.config8.spw2.robust0.5.image_co2_smaller_mm2_stack.png
# G333.23-0.06.config8.spw3.robust0.5.image_co1_smaller_stack.pdf
# G333.23-0.06.config8.spw3.robust0.5.image_co1_smaller_stack.png
# G333.23-0.06.config8.spw3.robust0.5.image_co2_smaller_mm2_stack.pdf
# G333.23-0.06.config8.spw3.robust0.5.image_co2_smaller_mm2_stack.png
# G333_spw0_mm2_stack.png
# G333_spw0_stack.png
# G333_spw1_mm2_stack.png
# G333_spw1_stack.png
# G333_spw2_mm2_stack.png
# G333_spw2_stack.png
# G333_spw3_mm2_stack.png
# G333_spw3_stack.png
# gallery.html
# spw1.png
# spw2.png
# spw3.png
# spw4.png
# style.css

# %%
from IPython.display import Image,display

# %%
for fn in glob.glob('spectra/figures/color*png'):
    display(Image(fn))

# %%
ls
# Out:
# cutout2.reg
# cutout3.reg
# cutout.reg
# G333.23-0.06.config8.cont_avg.selfcal_0.5_hogbom.image.fits
# G333.23-0.06.config8.spw0.robust0.5.image_co1_smaller.fits
# G333.23-0.06.config8.spw0.robust0.5.image_co2_smaller.fits
# G333.23-0.06.config8.spw0.robust0.5.image_small.fits
# G333.23-0.06.config8.spw1.robust0.5.image_co1_smaller.fits
# G333.23-0.06.config8.spw1.robust0.5.image_co2_smaller.fits
# G333.23-0.06.config8.spw1.robust0.5.image_small.fits
# G333.23-0.06.config8.spw2.robust0.5.image_co1_smaller.fits
# G333.23-0.06.config8.spw2.robust0.5.image_co2_smaller.fits
# G333.23-0.06.config8.spw2.robust0.5.image_small.fits
# G333.23-0.06.config8.spw3.robust0.5.image_co1_smaller.fits
# G333.23-0.06.config8.spw3.robust0.5.image_co2_smaller.fits
# G333.23-0.06.config8.spw3.robust0.5.image_small.fits
# NaCl_v_le_3_stackcube.fits
# spectra/

# %%
import glob
import spectral_cube.analysis_utilities
import reproject
from tqdm.notebook import tqdm

cbflist = (glob.glob('G333.23-0.06.config8.spw[0-3].robust0.5.image_co1_smaller.fits'))
for fn in cbflist:
    basename = os.path.split(fn)[-1].split(".fits")[0]
    try:
        cube = SpectralCube.read(fn, use_dask=True)
    except Exception as ex:
        print(ex)
        continue
    print(cube)
    scube = cube.subcube_from_regions(reg)
    mx = scube.max(axis=0)
    #msk = mx > 0.003*mx.unit
    print("Mean spectrum")
    sp = scube.mean(axis=(1,2))
    
    sp.write(f'spectra/{fn.split("/")[-1].replace(".fits","_meanspec.fits")}', overwrite=True)


    # reproject the velocity map into the cube's coordinate system
    vmap_proj,_ = reproject.reproject_interp(vmap,
                                             scube.wcs.celestial,
                                             shape_out=scube.shape[1:])
    vmap_proj = u.Quantity(vmap_proj, u.km/u.s)
    fits.PrimaryHDU(data=vmap_proj, header=scube.wcs.celestial.to_header()).writeto('vmap.fits')
    # convert to km/s with arbitrary rest value so 0 km/s can be interpreted
    if scube.spectral_axis.unit.is_equivalent(u.Hz):
        scube = scube.with_spectral_unit(u.km/u.s, velocity_convention='radio', rest_value=scube.spectral_axis.mean())

    print("Stacking")
    # perform the stacking!
    stack = spectral_cube.analysis_utilities.stack_spectra(scube, vmap_proj,
                                                           v0=0.0*u.km/u.s,
                                                           #progressbar=tqdm,
                                                           #num_cores=8
                                                          )
    fstack = stack.with_spectral_unit(u.GHz)

    pl.suptitle(f"{fn}")
    fstack.write(f'spectra/{basename}_mm1_stack.fits', overwrite=True)

    pl.clf()
    fstack.quicklook(filename=f'spectra/figures/{basename}_mm1_stack.pdf')
    fstack.quicklook(filename=f'spectra/figures/{basename}_mm1_stack.png')
    
    
    fig = pl.figure()
    mappable = pl.subplot(1,2,1).imshow(mx.value, origin='lower', interpolation='none')
    pl.colorbar(mappable)
    pl.subplot(1,2,2)
    pl.suptitle(fn)
    sp.quicklook()
# Out:
# DaskSpectralCube with shape=(3840, 48, 47) and unit=K and chunk size (3840, 48, 47):
#  n_x:     47  type_x: RA---SIN  unit_x: deg    range:   244.963547 deg:  244.963747 deg
#  n_y:     48  type_y: DEC--SIN  unit_y: deg    range:   -50.254109 deg:  -50.253979 deg
#  n_s:   3840  type_s: FREQ      unit_s: Hz     range: 233563396491.200 Hz:235438023434.076 Hz
# Mean spectrum
# Stacking
# DaskSpectralCube with shape=(3840, 48, 47) and unit=K and chunk size (3840, 48, 47):
#  n_x:     47  type_x: RA---SIN  unit_x: deg    range:   244.963547 deg:  244.963747 deg
#  n_y:     48  type_y: DEC--SIN  unit_y: deg    range:   -50.254109 deg:  -50.253979 deg
#  n_s:   3840  type_s: FREQ      unit_s: Hz     range: 219063352591.324 Hz:220937979534.200 Hz
# Mean spectrum
# Stacking
# DaskSpectralCube with shape=(3840, 48, 47) and unit=K and chunk size (3840, 48, 47):
#  n_x:     47  type_x: RA---SIN  unit_x: deg    range:   244.963547 deg:  244.963747 deg
#  n_y:     48  type_y: DEC--SIN  unit_y: deg    range:   -50.254109 deg:  -50.253979 deg
#  n_s:   3840  type_s: FREQ      unit_s: Hz     range: 231063388922.300 Hz:232938015865.176 Hz
# Mean spectrum
# Stacking
# DaskSpectralCube with shape=(3840, 48, 47) and unit=K and chunk size (3840, 48, 47):
#  n_x:     47  type_x: RA---SIN  unit_x: deg    range:   244.963547 deg:  244.963747 deg
#  n_y:     48  type_y: DEC--SIN  unit_y: deg    range:   -50.254109 deg:  -50.253979 deg
#  n_s:   3840  type_s: FREQ      unit_s: Hz     range: 216863345930.624 Hz:218737972873.500 Hz
# Mean spectrum
# Stacking

# %%
ls spectra
# Out:
# figures/
# G333.23-0.06.config8.spw0.robust0.5.image_co1_smaller_meanspec.fits
# G333.23-0.06.config8.spw0.robust0.5.image_co1_smaller_mm1_stack.fits
# G333.23-0.06.config8.spw0.robust0.5.image_co1_smaller_stack.fits
# G333.23-0.06.config8.spw0.robust0.5.image_co2_smaller_meanspec.fits
# G333.23-0.06.config8.spw0.robust0.5.image_co2_smaller_mm2_stack.fits
# G333.23-0.06.config8.spw1.robust0.5.image_co1_smaller_meanspec.fits
# G333.23-0.06.config8.spw1.robust0.5.image_co1_smaller_mm1_stack.fits
# G333.23-0.06.config8.spw1.robust0.5.image_co1_smaller_stack.fits
# G333.23-0.06.config8.spw1.robust0.5.image_co2_smaller_meanspec.fits
# G333.23-0.06.config8.spw1.robust0.5.image_co2_smaller_mm2_stack.fits
# G333.23-0.06.config8.spw2.robust0.5.image_co1_smaller_meanspec.fits
# G333.23-0.06.config8.spw2.robust0.5.image_co1_smaller_mm1_stack.fits
# G333.23-0.06.config8.spw2.robust0.5.image_co1_smaller_stack.fits
# G333.23-0.06.config8.spw2.robust0.5.image_co2_smaller_meanspec.fits
# G333.23-0.06.config8.spw2.robust0.5.image_co2_smaller_mm2_stack.fits
# G333.23-0.06.config8.spw3.robust0.5.image_co1_smaller_meanspec.fits
# G333.23-0.06.config8.spw3.robust0.5.image_co1_smaller_mm1_stack.fits
# G333.23-0.06.config8.spw3.robust0.5.image_co1_smaller_stack.fits
# G333.23-0.06.config8.spw3.robust0.5.image_co2_smaller_meanspec.fits
# G333.23-0.06.config8.spw3.robust0.5.image_co2_smaller_mm2_stack.fits

# %%
stackspectra = []
for ii,fn in enumerate(glob.glob('spectra/*_mm1_stack.fits')):
    pysp = pyspeckit.Spectrum(fn)
    basename = os.path.basename(fn)
    spl = basename.split(".")
    pysp.specname = f'{spl[0]}_{spl[4]}_mm1_stack'
    stackspectra.append(pysp)

# %%
overplot_saltlines(stackspectra, vcen=0*u.km/u.s, savepath='spectra/figures',
                   ymin=-20, ymax=150)
# Out:
# G333_spw0_mm1_stack
# G333_spw2_mm1_stack
# G333_spw3_mm1_stack
# G333_spw1_mm1_stack

# %%
ls spectra/figures/*mm1*
# Out:
# spectra/figures/color_labels_G333_spw0_mm1_stack.png
# spectra/figures/color_labels_G333_spw1_mm1_stack.png
# spectra/figures/color_labels_G333_spw2_mm1_stack.png
# spectra/figures/color_labels_G333_spw3_mm1_stack.png
# spectra/figures/G333.23-0.06.config8.spw0.robust0.5.image_co1_smaller_mm1_stack.pdf
# spectra/figures/G333.23-0.06.config8.spw0.robust0.5.image_co1_smaller_mm1_stack.png
# spectra/figures/G333.23-0.06.config8.spw1.robust0.5.image_co1_smaller_mm1_stack.pdf
# spectra/figures/G333.23-0.06.config8.spw1.robust0.5.image_co1_smaller_mm1_stack.png
# spectra/figures/G333.23-0.06.config8.spw2.robust0.5.image_co1_smaller_mm1_stack.pdf
# spectra/figures/G333.23-0.06.config8.spw2.robust0.5.image_co1_smaller_mm1_stack.png
# spectra/figures/G333.23-0.06.config8.spw3.robust0.5.image_co1_smaller_mm1_stack.pdf
# spectra/figures/G333.23-0.06.config8.spw3.robust0.5.image_co1_smaller_mm1_stack.png
# spectra/figures/G333_spw0_mm1_stack.png
# spectra/figures/G333_spw1_mm1_stack.png
# spectra/figures/G333_spw2_mm1_stack.png
# spectra/figures/G333_spw3_mm1_stack.png

# %%
for fn in glob.glob('spectra/figures/color*spw[0123]_mm1_stack.png'):
    display(Image(fn))

# %% [markdown]
# # Cutout 2 - mm2

# %%
# try creating a vmap based on another line
restval = 232.6867*u.GHz # 'H2Ov2=1_5(5,0)-6(4,3)': 
restval = 218.440063*u.GHz # CH3OH 4(2)-3(1)E1vt=0   <--- maybe a wrong line ID?
restval = 219.94944000*u.GHz # SO 65-54
vcen2 = -102*u.km/u.s # based on CH3OH line
vcen2 = -87*u.km/u.s
cube = [c for c in cubes2 if (c.spectral_extrema[0] < restval) & (c.spectral_extrema[1] > restval)][0]
scube = (cube.subcube_from_regions(reg2)
         .with_spectral_unit(u.km/u.s,
                                                          velocity_convention='radio',
                                                          rest_value=restval)
         .spectral_slab(vcen2-15*u.km/u.s, vcen2+15*u.km/u.s))
pl.figure(figsize=(14,5))
pl.subplot(1,3,1)
m0 = scube.moment0()
m0.quicklook()
pl.colorbar()

pl.title("m0")

pl.subplot(1,3,2)
mx = scube.max(axis=0)
mx.quicklook()
pl.title("mx")
pl.colorbar()
pl.subplot(1,3,3)
msk = (mx > 110*u.K) & (m0 > 1750*u.K*u.km/u.s)
msk = scipy.ndimage.binary_erosion(msk, iterations=1)
msk = scipy.ndimage.binary_dilation(msk, iterations=3)
pl.imshow(msk, interpolation='none', origin='lower')
pl.title('mask')
pl.tight_layout()
pl.figure()


from dask_image.ndmorph import binary_dilation, binary_erosion
m3d = (scube > 70*u.K).include()
m3d = binary_erosion(m3d, iterations=1)
m3d = binary_dilation(m3d, iterations=2)
m3d = m3d.compute()

m1 = scube.with_mask(msk).with_mask(m3d).moment1()
pl.figure(figsize=(14,6))
ax1 = pl.subplot(1,2,1)
im = ax1.imshow(m1.value, vmin=vcen2.value-10, vmax=vcen2.value+10)
pl.colorbar(mappable=im)
mxv = scube.with_mask(msk).argmax_world(axis=0)
pl.subplot(1,2,2)
pl.imshow(mxv.value, vmin=vcen2.value-10, vmax=vcen2.value+10)
pl.colorbar()


vmap2 = m1.hdu
# the rest value selected above was just the line center; we need to assume it's really 32 km/s off
#vmap.data = vmap.data
# Out:
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.argmax_world at 0x2b56689951f0>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]

# %%
from astroquery.splatalogue import Splatalogue
Splatalogue.query_lines(218.440062*u.GHz, 218.440064*u.GHz)
# Out:
# <Table length=2>
#   Species   Chemical Name Freq-GHz(rest frame,redshifted) Freq Err(rest frame,redshifted) Meas Freq-GHz(rest frame,redshifted) Meas Freq Err(rest frame,redshifted)      Resolved QNs     ... Lovas/AST Intensity E_L (cm^-1) E_L (K)  E_U (cm^-1) E_U (K)  Upper State Degeneracy Linelist
#    str11         str8                 float64                         float64                            int64                                int64                         str21         ...        int64          float64   float64    float64   float64         float64           str4
# ----------- ------------- ------------------------------- ------------------------------- ------------------------------------ ------------------------------------ --------------------- ... ------------------- ----------- -------- ----------- -------- ---------------------- --------
# CH3OHvt=0-2      Methanol                      218.440063                         1.3e-05                                   --                                   -- 4(-2,3)-3(-1,2)E,vt=0 ...                  --     24.3097 34.97603    31.59608 45.45944                   36.0     CDMS
# CH3OHvt=0-2      Methanol                      218.440063                         1.3e-05                                   --                                   --       4(2)-3(1)E1vt=0 ...                  --       24.31 34.97647    31.59638 45.45988                    9.0      JPL

# %%
import glob
import spectral_cube.analysis_utilities
import reproject
from tqdm.notebook import tqdm

cbflist = (glob.glob('G333.23-0.06.config8.spw[0-3].robust0.5.image_co2_smaller.fits'))
for fn in cbflist:
    basename = os.path.split(fn)[-1].split(".fits")[0]
    try:
        cube = SpectralCube.read(fn, use_dask=True)
    except Exception as ex:
        print(ex)
        continue
    print(cube)
    scube = cube.subcube_from_regions(reg2)
    mx = scube.max(axis=0)
    #msk = mx > 0.003*mx.unit
    print("Mean spectrum")
    sp = scube.mean(axis=(1,2))
    
    sp.write(f'spectra/{fn.split("/")[-1].replace(".fits","_meanspec.fits")}', overwrite=True)


    # reproject the velocity map into the cube's coordinate system
    vmap_proj,_ = reproject.reproject_interp(vmap2,
                                             scube.wcs.celestial,
                                             shape_out=scube.shape[1:])
    vmap_proj = u.Quantity(vmap_proj, u.km/u.s)
    fits.PrimaryHDU(data=vmap_proj, header=scube.wcs.celestial.to_header()).writeto('vmap2.fits')
    # convert to km/s with arbitrary rest value so 0 km/s can be interpreted
    if scube.spectral_axis.unit.is_equivalent(u.Hz):
        scube = scube.with_spectral_unit(u.km/u.s, velocity_convention='radio', rest_value=scube.spectral_axis.mean())

    print("Stacking")
    # perform the stacking!
    stack = spectral_cube.analysis_utilities.stack_spectra(scube, vmap_proj,
                                                           v0=0.0*u.km/u.s,
                                                           #progressbar=tqdm,
                                                           #num_cores=8
                                                          )
    fstack = stack.with_spectral_unit(u.GHz)

    pl.suptitle(f"{fn}")
    fstack.write(f'spectra/{basename}_mm2_stack.fits', overwrite=True)

    pl.clf()
    fstack.quicklook(filename=f'spectra/figures/{basename}_mm2_stack.pdf')
    fstack.quicklook(filename=f'spectra/figures/{basename}_mm2_stack.png')
    
    
    fig = pl.figure()
    mappable = pl.subplot(1,2,1).imshow(mx.value, origin='lower', interpolation='none')
    pl.colorbar(mappable)
    pl.subplot(1,2,2)
    pl.suptitle('mm2 '+fn)
    sp.quicklook()
# Out:
# DaskSpectralCube with shape=(3840, 39, 37) and unit=K and chunk size (3840, 39, 37):
#  n_x:     37  type_x: RA---SIN  unit_x: deg    range:   244.961927 deg:  244.962083 deg
#  n_y:     39  type_y: DEC--SIN  unit_y: deg    range:   -50.252987 deg:  -50.252882 deg
#  n_s:   3840  type_s: FREQ      unit_s: Hz     range: 219063352591.324 Hz:220937979534.200 Hz
# Mean spectrum
# Stacking
# DaskSpectralCube with shape=(3840, 39, 37) and unit=K and chunk size (3840, 39, 37):
#  n_x:     37  type_x: RA---SIN  unit_x: deg    range:   244.961927 deg:  244.962083 deg
#  n_y:     39  type_y: DEC--SIN  unit_y: deg    range:   -50.252987 deg:  -50.252882 deg
#  n_s:   3840  type_s: FREQ      unit_s: Hz     range: 216863345930.624 Hz:218737972873.500 Hz
# Mean spectrum
# Stacking
# DaskSpectralCube with shape=(3840, 39, 37) and unit=K and chunk size (3840, 39, 37):
#  n_x:     37  type_x: RA---SIN  unit_x: deg    range:   244.961927 deg:  244.962083 deg
#  n_y:     39  type_y: DEC--SIN  unit_y: deg    range:   -50.252987 deg:  -50.252882 deg
#  n_s:   3840  type_s: FREQ      unit_s: Hz     range: 233563396491.200 Hz:235438023434.076 Hz
# Mean spectrum
# Stacking
# DaskSpectralCube with shape=(3840, 39, 37) and unit=K and chunk size (3840, 39, 37):
#  n_x:     37  type_x: RA---SIN  unit_x: deg    range:   244.961927 deg:  244.962083 deg
#  n_y:     39  type_y: DEC--SIN  unit_y: deg    range:   -50.252987 deg:  -50.252882 deg
#  n_s:   3840  type_s: FREQ      unit_s: Hz     range: 231063388922.300 Hz:232938015865.176 Hz
# Mean spectrum
# Stacking

# %%
stackspectra2 = []
for ii,fn in enumerate(glob.glob('spectra/*mm2_stack.fits')):
    pysp = pyspeckit.Spectrum(fn)
    basename = os.path.basename(fn)
    spl = basename.split(".")
    pysp.specname = f'{spl[0]}_{spl[4]}_mm2_stack'
    stackspectra2.append(pysp)

# %%
overplot_saltlines(stackspectra2, vcen=0*u.km/u.s, savepath='spectra/figures',
                   ymin=-20, ymax=150)
# Out:
# G333_spw0_mm2_stack
# G333_spw3_mm2_stack
# G333_spw1_mm2_stack
# G333_spw2_mm2_stack

# %%
ls spectra/figures/*mm2*
# Out:
# spectra/figures/color_labels_G333_spw0_mm2_stack.png
# spectra/figures/color_labels_G333_spw1_mm2_stack.png
# spectra/figures/color_labels_G333_spw2_mm2_stack.png
# spectra/figures/color_labels_G333_spw3_mm2_stack.png
# spectra/figures/G333.23-0.06.config8.spw0.robust0.5.image_co2_smaller_mm2_stack.pdf
# spectra/figures/G333.23-0.06.config8.spw0.robust0.5.image_co2_smaller_mm2_stack.png
# spectra/figures/G333.23-0.06.config8.spw1.robust0.5.image_co2_smaller_mm2_stack.pdf
# spectra/figures/G333.23-0.06.config8.spw1.robust0.5.image_co2_smaller_mm2_stack.png
# spectra/figures/G333.23-0.06.config8.spw2.robust0.5.image_co2_smaller_mm2_stack.pdf
# spectra/figures/G333.23-0.06.config8.spw2.robust0.5.image_co2_smaller_mm2_stack.png
# spectra/figures/G333.23-0.06.config8.spw3.robust0.5.image_co2_smaller_mm2_stack.pdf
# spectra/figures/G333.23-0.06.config8.spw3.robust0.5.image_co2_smaller_mm2_stack.png
# spectra/figures/G333_spw0_mm2_stack.png
# spectra/figures/G333_spw1_mm2_stack.png
# spectra/figures/G333_spw2_mm2_stack.png
# spectra/figures/G333_spw3_mm2_stack.png

# %%
for fn in glob.glob('spectra/figures/color*mm2_stack.png'):
    display(Image(fn))
